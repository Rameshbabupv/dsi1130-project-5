# %% [markdown]
# # Project 5: Group Project
# #### Author: Adam Pardo, Brandon Bergeron, Eric Bayless, Ramesh Babu

# %% [markdown]
# ### 01 - Data Collection and Data Cleaning

# %% [markdown]
# Task:

# %% [markdown]
# Information:

# %%
# import libraries here 
import pandas as pd
import os

# %%
# import Business.json
business_json_path = './data/yelp_academic_dataset_business.json'
business = pd.read_json(business_json_path, lines=True)

# %%
# function to pull business dataset by city, with or without sampling

def city_restaurants(business_json, city_name, samples=None):
    #--load restaurants in city_name
    location = business_json[business_json['city'] == city_name]
    location = location.dropna(subset=['categories'])
    
    #--keep restaurants with reviews between 100-300
    location_rest = location[location['categories'].str.contains('Restaurant')]
    location_rest_small = location_rest[(location_rest['review_count'] > 100) & (location_rest['review_count'] < 300)]
    location_rest_small.reset_index(drop=True, inplace=True)
    
    #--returns all restaurants if no samples
    if samples == None:
        location_rest_small.to_csv(f'./data/{city_name.replace(" ", "_")}_restaurants.csv', index = False)
        return location_rest_small
    
    else:
        #creation of sample restaurants
        sample_rest = pd.concat([location_rest_small[location_rest_small['is_open'] == 1].sample(samples), location_rest_small[location_rest_small['is_open'] == 0].sample(samples)])
        sample_rest.reset_index(drop=True, inplace=True)
    
        sample_rest.to_csv(f'./data/{city_name.replace(" ", "_")}_{samples*2}.csv', index = False)
        return sample_rest

# %%
# import Review.json
review_json_path = './data/yelp_academic_dataset_review.json'
size = 500_000
#rows = 1_000_000

review_reader = pd.read_json(review_json_path, lines=True,
                      dtype={'review_id':str,'user_id':str,
                             'business_id':str,'stars':int,
                             'date':str,'text':str,'useful':int,
                             'funny':int,'cool':int},
                      chunksize=size)

# %%
def business_reviews(review, business_filepath, output_filepath):
    df = pd.read_csv(business_filepath)
    chunk_list = []
    
    for chunk_review in review:
        chunk_review = chunk_review.drop(['review_id','useful','funny','cool'], axis=1)
        chunk_review = chunk_review.rename(columns={'stars': 'review_stars'})
        chunk_merged = pd.merge(df, chunk_review, on='business_id', how='left')
        print(f"{chunk_merged.shape[0]} out of {size:,} related reviews")
        chunk_list.append(chunk_merged)
        
    df_reviews = pd.concat(chunk_list, ignore_index=True, join='outer', axis=0)
    
    df_reviews.dropna(subset=['text'], inplace=True)
    df_reviews.reset_index(drop=True, inplace=True)
    #uncomment if you want csv of business in given city
    df_reviews.to_csv(f'{output_filepath}', index = False)
    return df_reviews

# https://towardsdatascience.com/converting-yelp-dataset-to-csv-using-pandas-2a4c8f03bd88

# %%
# function that joins city business information with yelp reviews
business_reviews(review_reader, './data/Las_Vegas_400.csv', 'Las_Vegas_400_reviews.csv')
# Out:
# 5081 out of 500,000 related reviews
# 4630 out of 500,000 related reviews
# 5014 out of 500,000 related reviews
# 5035 out of 500,000 related reviews
# 4368 out of 500,000 related reviews
# 5158 out of 500,000 related reviews
# 5314 out of 500,000 related reviews
# 5193 out of 500,000 related reviews
# 5823 out of 500,000 related reviews
# 4862 out of 500,000 related reviews
# 5364 out of 500,000 related reviews
# 4758 out of 500,000 related reviews
# 4682 out of 500,000 related reviews
# 4807 out of 500,000 related reviews
# 4218 out of 500,000 related reviews
# 4293 out of 500,000 related reviews
# 477 out of 500,000 related reviews
#                   business_id                    name              address  \
# 0      409qhf4RF0rlxcuaM576Qg           El Pollo Loco     5260 S Ft Apache
# 1      409qhf4RF0rlxcuaM576Qg           El Pollo Loco     5260 S Ft Apache
# 2      409qhf4RF0rlxcuaM576Qg           El Pollo Loco     5260 S Ft Apache
# 3      409qhf4RF0rlxcuaM576Qg           El Pollo Loco     5260 S Ft Apache
# 4      409qhf4RF0rlxcuaM576Qg           El Pollo Loco     5260 S Ft Apache
# ...                       ...                     ...                  ...
# 73273  1qTx9z8RMz7RIYKAfnpZ0A  Lillie's Asian Cuisine     129 E Fremont St
# 73274  INzLc1Y0JNQzIHjPH2Nbeg       Fuzzy's Taco Shop  7080 S Rainbow Blvd
# 73275  INzLc1Y0JNQzIHjPH2Nbeg       Fuzzy's Taco Shop  7080 S Rainbow Blvd
# 73276  INzLc1Y0JNQzIHjPH2Nbeg       Fuzzy's Taco Shop  7080 S Rainbow Blvd
# 73277  INzLc1Y0JNQzIHjPH2Nbeg       Fuzzy's Taco Shop  7080 S Rainbow Blvd
#
#             city state  postal_code   latitude   longitude  stars  \
# 0      Las Vegas    NV        89148  36.094100 -115.296839    2.5
# 1      Las Vegas    NV        89148  36.094100 -115.296839    2.5
# 2      Las Vegas    NV        89148  36.094100 -115.296839    2.5
# 3      Las Vegas    NV        89148  36.094100 -115.296839    2.5
# 4      Las Vegas    NV        89148  36.094100 -115.296839    2.5
# ...          ...   ...          ...        ...         ...    ...
# 73273  Las Vegas    NV        89101  36.170349 -115.144506    3.5
# 73274  Las Vegas    NV        89118  36.060044 -115.241666    3.5
# 73275  Las Vegas    NV        89118  36.060044 -115.241666    3.5
# 73276  Las Vegas    NV        89118  36.060044 -115.241666    3.5
# 73277  Las Vegas    NV        89118  36.060044 -115.241666    3.5
#
#        review_count  is_open  \
# 0               108        1
# 1               108        1
# 2               108        1
# 3               108        1
# 4               108        1
# ...             ...      ...
# 73273           121        0
# 73274           252        0
# 73275           252        0
# 73276           252        0
# 73277           252        0
#
#                                               attributes  \
# 0      {'RestaurantsAttire': "'casual'", 'GoodForKids...
# 1      {'RestaurantsAttire': "'casual'", 'GoodForKids...
# 2      {'RestaurantsAttire': "'casual'", 'GoodForKids...
# 3      {'RestaurantsAttire': "'casual'", 'GoodForKids...
# 4      {'RestaurantsAttire': "'casual'", 'GoodForKids...
# ...                                                  ...
# 73273  {'OutdoorSeating': 'False', 'RestaurantsGoodFo...
# 73274  {'RestaurantsTableService': 'False', 'Restaura...
# 73275  {'RestaurantsTableService': 'False', 'Restaura...
# 73276  {'RestaurantsTableService': 'False', 'Restaura...
# 73277  {'RestaurantsTableService': 'False', 'Restaura...
#
#                                               categories  \
# 0                        Restaurants, Mexican, Fast Food
# 1                        Restaurants, Mexican, Fast Food
# 2                        Restaurants, Mexican, Fast Food
# 3                        Restaurants, Mexican, Fast Food
# 4                        Restaurants, Mexican, Fast Food
# ...                                                  ...
# 73273  Casinos, Restaurants, Chinese, Hotels, Arts & ...
# 73274   Tex-Mex, Mexican, Sandwiches, Salad, Restaurants
# 73275   Tex-Mex, Mexican, Sandwiches, Salad, Restaurants
# 73276   Tex-Mex, Mexican, Sandwiches, Salad, Restaurants
# 73277   Tex-Mex, Mexican, Sandwiches, Salad, Restaurants
#
#                                                    hours  \
# 0      {'Monday': '0:0-0:0', 'Tuesday': '9:30-23:0', ...
# 1      {'Monday': '0:0-0:0', 'Tuesday': '9:30-23:0', ...
# 2      {'Monday': '0:0-0:0', 'Tuesday': '9:30-23:0', ...
# 3      {'Monday': '0:0-0:0', 'Tuesday': '9:30-23:0', ...
# 4      {'Monday': '0:0-0:0', 'Tuesday': '9:30-23:0', ...
# ...                                                  ...
# 73273  {'Monday': '17:0-0:0', 'Tuesday': '17:0-0:0', ...
# 73274  {'Monday': '10:0-22:0', 'Tuesday': '10:0-22:0'...
# 73275  {'Monday': '10:0-22:0', 'Tuesday': '10:0-22:0'...
# 73276  {'Monday': '10:0-22:0', 'Tuesday': '10:0-22:0'...
# 73277  {'Monday': '10:0-22:0', 'Tuesday': '10:0-22:0'...
#
#                       user_id  review_stars  \
# 0      GmXOSEbXy8JXmvo9hM5WWQ           2.0
# 1      P8Rn03SOJg0NnExbOWhLZw           1.0
# 2      qPVtjjp8sNQ32p9860SR9Q           3.0
# 3      hk6B1ZdzI62jMGo6e2IuuA           1.0
# 4      iNmUdP_AtwHIVMHAg6mMSA           1.0
# ...                       ...           ...
# 73273  5xaFHey_NjidLtugo0mdAw           3.0
# 73274  acyl_5237y5MZMgnx_VeNA           5.0
# 73275  o-4WGmqWdNiiQFctHdjC8Q           4.0
# 73276  HyDMhqf_ru13zau_OCyNBw           1.0
# 73277  OVua8dER76E3doOupwWc-g           4.0
#
#                                                     text                 date
# 0      Came here quickly today to grab a burrito with...  2015-09-09 23:09:37
# 1      I really like el pollo loco but some things no...  2014-04-20 03:16:46
# 2      El pollo loco is what it is this place is a co...  2017-01-15 00:43:57
# 3      Busy place with a lot of traffic.. the price i...  2018-05-19 03:45:05
# 4      My burrito was cold. My wife's chicken was dry...  2018-05-19 18:50:08
# ...                                                  ...                  ...
# 73273  Sitting here for what seems like it has been f...  2019-10-13 04:25:49
# 73274  I remember this chain from Texas and LOVE it!!...  2017-03-25 19:55:57
# 73275  Love Fuzzy's Taco Shop.  It's become my new ad...  2017-01-11 19:53:55
# 73276  Found a part of a rubber glove in my tacos.  W...  2017-08-15 19:23:56
# 73277  I'm from Texas and have been to many Fuzzy's o...  2016-10-19 00:28:15
#
# [73278 rows x 18 columns]
